# %%
import keras
import numpy as np
# path = keras.utils.get_file(
# 'data/nietzsche.txt',
# origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')

path = 'data/nietzsche.txt'
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Corpus length: 600901

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# WARNING:tensorflow:From C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200281/200281 [==============================] - 280s 1ms/step - loss: 1.9815
# --- Generating with seed: "as a feeling of
# mutual relationship, resulting in a mutual i"
# ------ temperature: 0.2
# as a feeling of
# mutual relationship, resulting in a mutual in the scienters of the propersing in the schood the such a the profound of the such a man it is the scienters of the evention of the station of the such a moral stand the stand and the such a perhation of the profound and the scienters of the scienters of the scienters of the scienters of the such all the profound the schood the scienters and the sciented in the tanding the religious religious and------ temperature: 0.5
#  and the sciented in the tanding the religious religious and conducess of the preceations of the serf, or a any all a conscience under there all believe would will all
# add as a man indient, in the eventhical also truest of the spirted and many and call the
# singlist also wild there is a mates and mankes and ord the disprofounds, there rears wither only the many as a low becoure in them and the probectaying the become all believe in the spich hist
# also and s------ temperature: 1.0
# ectaying the become all believe in the spich hist
# also and spripmous frienbl, pude turn. in epildical mepation itself undod for the eloked
# and the risingrerian, of will acr before orderich time all charl. whill beface, which call mastect, for ani truture; breveroald putuper.
#
#
# dgr will necess, "the
# the still rual, which will, due and it, hal coursely of ancestncted," as helling thelib, a caonge authating, it all the . sadamental to the kind and upon all ya------ temperature: 1.2
# thating, it all the . sadamental to the kind and upon all yavitions spirok, is mb.
# onemorcentsiby mabicaniwiccet the promiting
# cradolratiols""--clopiblateess. whot preesaetns, of secrecy-by an
#  nurks beelly vidous--wii lw id there its
# (as is the seest
# putural, to terson at axphation of pethops,
# in wus tulwes ale as ewi. femil" enavens--stasding atopalfurous riab sufervore fund tankus watt whe evence
# fa ccanaile; are disournquestionmeem, dow
# notedr, which eepoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 258s 1ms/step - loss: 1.6279
# --- Generating with seed: "penhauer's
# religio-ethical human and cosmical oracle as rega"
# ------ temperature: 0.2
# penhauer's
# religio-ethical human and cosmical oracle as regard and such a delication of the self-present of the such a strudge in the self-pass of the same of the such all the such a superst and in the such a superst and the self and of the selfing and such the superst and the such a sure and and such a superst of the spirit of the superst of the self-part of the superst of the self-path and all the superst of the superst of the self-part of the such desti------ temperature: 0.5
# he superst of the superst of the self-part of the such destiness in should as he was the morality grantic of the precompaling unconduct of the scientifies and present the culture of present; and innoctually bether of
# spirit and well "self--a conscience in the look any the more great present and such all is the present
# of where himself the moral the really and becomes the real has a chuld self-called the real a strime, on the preselving also manamoriality a------ temperature: 1.0
# ed the real a strime, on the preselving also manamoriality and peralves the means oen lone dass, valuable have nectules, and not with utterice, in the long a the liblations.
#
#
#  s the decedualicand--that im furmer desidate untactually megality not traded thetefhered he voucd the moral ohren action, in the world--like the woman for well alsusten that man and have time, there is attelves then otherss and ale as eaker of the dolunathing the philosopher the sce------ temperature: 1.2
#  and ale as eaker of the dolunathing the philosopher the sceptar of
# prespexgnas embinatactity for anord an orgragy or what above the fean
# pre1ions, that he greecles" relations unistantolomewdys otherstorious the iduever, or the
# burie cabous, the newsly, old mohtives. realticy mexis.=--their how your all new there doe and stand, the wellity--thecy else is whollibys
# as agosoug, nocld yout at the isus. they hude=--as us leaghes he
# be
# augarally, and
# always, daepoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 235s 1ms/step - loss: 1.5406
# --- Generating with seed: " other
# extreme of all modern ideology and gregarious desirab"
# ------ temperature: 0.2
#  other
# extreme of all modern ideology and gregarious desirable to the profound and such a soul the wholly he seephy to the sense and such a something the sense of the same the sense of self--which the present the sense in the sense in the religious any the sense of the sense in the considerations of the sense and considerations of the destruct to prompted to the considerations of the seems to the persperical consideration of the self-also any other pertain------ temperature: 0.5
# persperical consideration of the self-also any other pertain of an attifice
# and we every of the east seems of consideration of the consequent their will so intiture his all their look of inspire of the sense and such any operation of believed and secreced and "fact sense with the case of one of the cause in the sense and gares of certain of its spired to look and the prompten to which i consequent and distimal spich so the relation. the suight to such a su------ temperature: 1.0
#  and distimal spich so the relation. the suight to such a such   ; wlat eith lorical when where morougd, which will to
# be getordidely wast veryns he say: in the tere their kings, and the dicramsr and esjoct of the groutt man, he baru enwhund with a (wholly onct than the learnt, to impressing, extned ends to be dracually amond a
# unfliliness, their
# other periop of greatest
# he seems often biod, of their incated, and only noble, only "khet he with its xacpil c------ temperature: 1.2
# eir incated, and only noble, only "khet he with its xacpil convess of canlosm sougtrish trutupsne essade myster three !a becomes inlixuked ago, those pertaint, breah a dericable frimting nace odignal enterebly, we sen modests him et whond than
# a geven
# sose requireraying very oun yout fese, axresiftive.
# eashy is.--however a hrowgh youre pertair: it yatter-gritt in
# rotrigh to poid what hastified itnly conscace, be earth--the agremogely an me "factuoes for gepoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 247s 1ms/step - loss: 1.4953
# --- Generating with seed: "which is no voucher for the validity of
# knowledge, as intens"
# ------ temperature: 0.2
# which is no voucher for the validity of
# knowledge, as intense and present and act of the command of the saint of the saint of the command of the same to a believe the problem of the command the spiritual soul of the science of the self self the course of the sense of the spiritual strong and all the science of the strong of the sense of the spiritual soul a person of the spiritual course of the spiritual present the course of the command of the strong to t------ temperature: 0.5
# iritual present the course of the command of the strong to the supposes and the contraduates and elikents of the desire and courte of the acceener stopies of the science of the faith and respect the soul of the souls it is as the sphole the discovere of the something of the soul in the belie of the comparison of the spiritual perventual his only the belief in the fact that stand the could as the complese and anything will the some counted to the case of co------ temperature: 1.0
# omplese and anything will the some counted to the case of conflard to
# hume: our semmer syot the hard to groutc or wholl srimad an scerming so soul and s quest of a counter areerst of consciely meordersely oneself marntes: or leaded femous lution (womans is the f
# ituaricity of from his not would other weakest liguted eurallognes, to it with the plato who dufing world for faked, and bad cally will religion of him lenours slavpaterful, them, a reconclusion
# of------ temperature: 1.2
# eligion of him lenours slavpaterful, them, a reconclusion
# of the sah, religous ruly: then.--dre valce of tauves fundage these other the order the
# auttorious profussod to an its obsive there and he puliabo alworike finpert. humbuch ingod out
# di so civility, cony the religious--aps something would if a may exagure of thy ocrmost of who the
# couptest
# maltiisdly rekelt its question of the
# dreeved met "mones, it is-riltifiedment persiourally, desuit hel qpest foepoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 236s 1ms/step - loss: 1.4650
# --- Generating with seed: " the existence of immorality (wherein it would be really
# des"
# ------ temperature: 0.2
#  the existence of immorality (wherein it would be really
# destray to be a more in the conduct of the spirit of the most love and pervated and strange of the same to be a strength of the same to the sense of his soul of the most powerful and strange of the conduct of the same to be do and the pervation of the same concealm of the concealm of the sense of the concealed of the present the conceptions of the perfectless of the false of the conceptions of the ex------ temperature: 0.5
# of the perfectless of the false of the conceptions of the experienced, when there even of really as the most whe hear in artists in which is all the farible and most course of still when whe one who has necessaris to our an act to even who he simply the proves of the present and point of the sense of the bad in the superhaple and ages of the popusity of the false of himself continued that all the brult of what does now at learned in the faith of the end of------ temperature: 1.0
# brult of what does now at learned in the faith of the end of
# vanied: "he case of sportan to ouself, and by to the ays shall, the f
# man from it. whech in fultimes also have
# their ttent warty and more acgening be fait than thower also morality, one involuntarily crude away, bad elects insyine of
# the putsi traw, something sometes he
# and a happiness the scientific what all have so
# are fought to have alen to thas it not piving eyes to polupity. for
# hethert not ------ temperature: 1.2
# len to thas it not piving eyes to polupity. for
# hethert not nich-yible thought--polis,
# we contemplating
# intole--
#
# 2prilly on
# the corrim
# to socies after-want, wised which views
# his lifted
# an isture in an old becompezh even of vohiny in it?
#
# . furct more advasucaiiserst--saysivaties,orix-pleaanceness, justed," imsoulves ater bad's the dahi 4quaruiss": sunmitionally no
# mind, lookad la=ke ideast of id-arcevin to
# c up a sudgenly,
# be axidit, at mussiun
# new and epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 244s 1ms/step - loss: 1.4425
# --- Generating with seed: "f.=--the philosophers are in the habit of
# placing themselves"
# ------ temperature: 0.2
# f.=--the philosophers are in the habit of
# placing themselves be a state of the state of the conscience of the constant the state in the same to the desired to the individual and superficial seem of the same to the same to a men and supposite and superficial to the superficial to the morality of the superficial to the subjunt the same to the look the spirit the same to the hund the seems to the end the subjuct and one is a state of a state of the state of t------ temperature: 0.5
#  the subjuct and one is a state of a state of the state of the saint one of promuce to the other despectation and seems to the counters. which is to which the individual moral and as the preservences and probable to soul of spoile in which his comprise to the word
# the same propen to the greek of the soutt of the wast to their the susception of the surernation to be a subjutt with the same to much the feeling of the look and self-east who are the consequent------ temperature: 1.0
# the feeling of the look and self-east who are the consequent to the to
# health
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  ourselves? rialisted with the german he capacing and
# ruged the soutuotricy on order whichumorate virtue who is even with opposition would put i all
# dependuded hitherto not many or all remain it also, but a other wort, ever
# delicate as i mea" indoes to geriss upen them former conscience. subjuss by gives (which
# we make indifferent, a faston, most why hitherto
# to a hitherto hithert------ temperature: 1.2
# different, a faston, most why hitherto
# to a hitherto hitherto
# beasting
# half-ideas
# flog!t hapminy is heopicd.
#
# 21t ip mustial liberty the long concaare
# lown when of thinking, is
# cooar abows betrave by meing the
# anwart offess
# transearde sent chiedfuly communically-dners in
# by symper, in rend!
#
# se swhorty,
# every oneswaf probnomage and dild, and
# years rewilepr, enford of german will percesspon and iswad for their general hagy onr
# just an thise and foctr, i whoepoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 243s 1ms/step - loss: 1.4268
# --- Generating with seed: "f style, are developed in profuse variety among germans--par"
# ------ temperature: 0.2
# f style, are developed in profuse variety among germans--partic to a person and and the sense of the sense of the sense of the self-power of the sense of the partial called the formerly and the sense of the sense of the sense of the same that the religion of the sense of the sense of the sense, and as a person of the sense of the moral the sense of the self-distraction of the sense of the self-conscience, and all the sense of the fathers and and sense of t------ temperature: 0.5
# science, and all the sense of the fathers and and sense of the sense and because of the incerint
# and desires and the desire of the made of the religion and the series which is all the deserted and stand the way who heart--and as in the religion, the constituted, and desired to be age of the heart of the reading entire and speak and the self-world
# may be we an antitude of our hististing and with aristoon and
# sympathy considerations of a tention and storic f------ temperature: 1.0
# istoon and
# sympathy considerations of a tention and storic free spirit
# there
# excess of the
# pertaingered of many
# point, i called individuals or "unselfach read lowere for which to break a may on their
# master and intalle his brainally, to usience,h out of a hating against all contelted to well, more of good pupposing the eterning
# your
# anter voluntary germans not reponci, hand, are
# recions who
# art
# coance spilit from it: if old most worth of laterates thet his------ temperature: 1.2
# ance spilit from it: if old most worth of laterates thet his
# incesser,
# braption just ambirrd. deception, and (so withiod
# once reasontdfous the
# croryly be ph"yox to be bling-determinaslypgen, always find their ensing, however is truth, of
# it
# with burtyblakmeredo my
# setiins to boor, mays, to sigus cinyugablez.
# ind-east,
# hence this after as regleated as imposingy hiftyness," they sadity in arhith,
# cfult kne of h glempery.
# moralatepemfnting. voluntally
# in
# the epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 243s 1ms/step - loss: 1.4113
# --- Generating with seed: "t
# and their shame, "it always finds things out!"). the decla"
# ------ temperature: 0.2
# t
# and their shame, "it always finds things out!"). the declace and superstition of the same to be a strongest in the same taste of the superlicism of the same take to the same take to be art of the same taste of the profound to the morality of the morality, and superficial to be art of the same to the same command the morality of the same taste of the same talk and supersticional the morality of the superstition of the same take to means of the same take t------ temperature: 0.5
# he superstition of the same take to means of the same take to a sentence of the morality and subject of the greatest of communic to be actiness and say the best for the age in his overlite to the morality establing of the morality. the discontrained his discommand in the common the commences to be strongest in the from the world of many obself the spirit more and find his ame, and so the common in the fars of the sense of a god and sacrificed to love of th------ temperature: 1.0
#  the fars of the sense of a god and sacrificed to love of thenolongn-race, as he hen e on
# woroning century
# borm in believe doven cid, as lacks, as know, bee a chisely of belogions. tigening which,
# flowing and disfold with ruling able time, opinion
# that no fair efter miderod pupal its term of
# thingligh with a right.--feringh-riking oneself is even there of monement of the belong the language, as up, of artistage itstwness, who eas, as even the hand, once ma------ temperature: 1.2
# , of artistage itstwness, who eas, as even the hand, once mativous skrond i entini-gow whatever is florce he dy bribied the nest,
# the soul that
# should nothing
# isy particly
# of truth; hem be be force foom which is, is neworive educonogom loftaratithly religioi:ma,
# o !s prientw be one, anyication, as to be
# is comparas it art and soceity is understand it varifations, rachpi enside us amousion. at artistens, "day lexuly pretiso withins which
# there, resslutions epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 241s 1ms/step - loss: 1.3996
# --- Generating with seed: "t may be otherwise--"better," if
# you will; there there may r"
# ------ temperature: 0.2
# t may be otherwise--"better," if
# you will; there there may really and such a command the power of the soul of the fathers without the present the said, and the present the said how to the present the present of the present to the moral problem and such a strength to the most conscience to the present of the contempt to the said and such a condition of the fact that the said, and the same to the spirit of the said to an interpretation of the present and and------ temperature: 0.5
# irit of the said to an interpretation of the present and and in the most soul has also the condition of the happiness of the love and every
# men as the most particle and something that the said such prose only when the time and interpretation of listing, the condition of the word the conviventally truth, there is not are a words is the problem and only self-soul, and it is fing and thinken the perhaps also the such a man in the age else in its variate of th------ temperature: 1.0
# aps also the such a man in the age else in its variate of the pride and coverly make it righ his workgwil on this ascethon, acts the lood. the doubt it is", the favalt", to made tour? when they should we always a sensible or
# sucriaticy" singula, even and en moral own self-dotentuality of vinungeful to knows, custond
# who really, in the natures refined possibility believe much, kind (and laou-godds, who is once praw. show, when he says the place--thinkx--at ------ temperature: 1.2
#  who is once praw. show, when he says the place--thinkx--at ally editwan
# only from to other wick weln, which
# necessary of discript, what, are not within dispanianianly!, why a i
# by too, counder proporty
# inflicted
# an else him--very diventugner--polestion, ordul, day from
# expysizarce between en genure, so "brund, to conking noblign
# he last ceriolant the ken at feelly or wither then
# that of wi takalvire, and
# philosophy with the world.
#
# to he loof at
# tonakenoepoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 227s 1ms/step - loss: 1.3896
# --- Generating with seed: "ecides in favor of the
# strongest--as the phrase has it, alth"
# ------ temperature: 0.2
# ecides in favor of the
# strongest--as the phrase has it, although and the superficient to the standard of the same talted to the senses of the spirit and and an again and attempted to the superficier and the superficier of the same to the senses of the senses of the really and and the same and an intelliges to the superficiently the same to the superficier and such a superficient to the soul. the superficies of the superficied and such a command the princip------ temperature: 0.5
# uperficies of the superficied and such a command the principle to the same to instinctions to the superficied and heart of
# the problem and to be carries of the contradices of the faith in the fact that in the same not of the constantly and concealed and the longed in the self mankind of the god have ever we see only the literate from the great here or even the superficiently the same and standard of this the free spirits and involved and conscience of the ------ temperature: 1.0
# of this the free spirits and involved and conscience of the sair socialize," rogust that which croticle
# beay s ? that diceation, them and distinguat refultfuls as it is nimhies
# scholarsly benend"spocred outily, even cheticink of
# oldow with its wated to us become city, rendations with to us stupidity of that
# "sought every sate, some
# fuse. the enough to casth into the sense of old of right by which have human diem priocial
# are can always cickmunes" rekind wh------ temperature: 1.2
# have human diem priocial
# are can always cickmunes" rekind which nations, romaaler from the bind ant "umas fraelly
# recalinance bedies, which elration--anded, anrent) as great envmides
# definite bering too falsaciquas blection, and ressenness befotterd
# the idea could "is nothily, pluturi, he
# questele is accient, atomdness e nucious it is banes whom
# depth, too regard in any to them seritions. "we priscense," in goduhe. it is-dood"
# of
# such though ourselves now epoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 231s 1ms/step - loss: 1.3814
# --- Generating with seed: "bad"
# with deliberate injury to one's neighbor or community. "
# ------ temperature: 0.2
# bad"
# with deliberate injury to one's neighbor or community. the problem and self-really the proper and in the sense of the command--it is a super-all the proposes the present and all the present and such an an an an and the demands and as the command; and is all the present, and is not be a story in the self-really becomes the condition of the contrary in the command--it is all the condition of the seem to the world and the power of the problem of the comm------ temperature: 0.5
# e seem to the world and the power of the problem of the common is such an end and in the desist the other is an althing, the same to which one has has also the condition of the desist and intellectual condicting and destraction of the
# would be in our spirit. at helise and such a means of a really bad is not in the other was secret in the deserved of the point in the demanded and deman the command--it is fact the distrust and in such a world than the proble------ temperature: 1.0
# -it is fact the distrust and in such a world than the problem personal sonounsment, generacly; and in "disturring a command permatication--purabicd and history inordinary secir taken
# look of the curratic bly own is-knownw=? unt newopicism and to they had it anteenceer society in this solitude,
# lasting, in usly, "fal and lapsing, and can so
# rod and new dangleth.
#
#
# h0zing so most fastion and ourselves
# noticatinances, i store before and very of the gond and
# o------ temperature: 1.2
# es
# noticatinances, i store before and very of the gond and
# oftrliars
# coaves, was inson too happinermgn and
# it school and letst sucient
# to an han twharnowncould, serking command?
# one whysy orireed in which possible? its made, it saight of changefacy of an inscioner of languable, seek--so hous-rennderful to, who disyoperfblle
# takes them it agay too, they oryines?
# de for come, with sgrts,ing
# ourselvisament;
# buting of acplantgen a
# dubliously,
# there are missposepoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 225s 1ms/step - loss: 1.3717
# --- Generating with seed: "re which we were taught to pray--their
# sublimest moments wil"
# ------ temperature: 0.2
# re which we were taught to pray--their
# sublimest moments will the proved the superficial and superioristic and conscience, and the superiorishes the finer of the sentent the suppose the sentently and still and and a standards of the stronger and and the superficial and superioristic and supposed them such a soul and and suppose the suppose and such a soul and all the same to be a soul and desire to be a standards of the superficial and such a sentiment of ------ temperature: 0.5
# o be a standards of the superficial and such a sentiment of the superiorished of the science of supposent in all the spirit and an individuals in the free fact and the spection of free spirits with an anticides the same
# the sentiment of the depressions of the superstite to whom even the such we may necessity, although harding to the spection and still them have been of their sense of the profound stand to the staplier were such a disciple of character in t------ temperature: 1.0
# stand to the staplier were such a disciple of character in the profuce your believes--to harding
# nature, that is hardings; oneher and "into the ascraapardy a prescorvation
# are to cretrupten torirs of not mediocrical undlyssesming thelw is mastery. the greatest thinks, who the first actor anfarcical contembing, breaks, even an additionally for the supportles in the souls whoruching
# by hate anieshal developppined; not
# y -all power, more perman to their desir------ temperature: 1.2
#  developppined; not
# y -all power, more perman to their desireed, ani wishorr: feel the bast loves his greatem readiation some tission its _music? of is univ: no worlds that ofenes's euron
# "wounds of pleusibable weakly people over thever a chainges is more long other one may, from great oldint without more
# contradily suffect wneeh to be
# detincop to presconted to have elehtism and benestrillityy that thiss wails set
# adtjene? on cavely
# dependings and through epoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 230s 1ms/step - loss: 1.3654
# --- Generating with seed: "eligious. that which was brought to him by the popular
# faith"
# ------ temperature: 0.2
# eligious. that which was brought to him by the popular
# faith, and desirations of the states of the super-as the states that the still and the best that the state, and such a super-as the super-as the self and suppositions of the super-as the super-as a man who is the states and super-or the problem and propour and the problem of the states of the states and still the false of the such the stalsations of the contradictly and subject of the comparity of the ------ temperature: 0.5
# ons of the contradictly and subject of the comparity of the "etent and the problem the proved and such a religions of the still, the fearly that an order, and one anothers of the contemporious interpretant the compars the state, the problems, and and surely for the subject that the desire their saw conduct of a man who a surerst and moral man with the problems and an antight of the best or and developed of the sigaral
# are in all self as the super-instinct,------ temperature: 1.0
# eloped of the sigaral
# are in all self as the super-instinct, on-class.    'de's things he it it in the delusion, feeling naturally leadn, all the birdical to fundagains usuner, propin vare dinge, and sympathy, order, therein are social
# highes belicuation itstalsoness which had good taste"!.--the men of little also instalter, and ofter
# bad cadew understand there has honoury most prequiraly ethicanceation of these infloocted, how in its wortow of "thrab most------ temperature: 1.2
# eation of these infloocted, how in its wortow of "thrab most valuety, new comprwhess in devertequer-grows bung, and which
# what venervale, perhaps pyrace
# through that all for excectionsful rapl ewolance, flaction
# who all general, sembland, this in more happyses especialeable
# taste.--sigath, and veghtismwer how glorific signichs could virtue of theumos with ueferinvariasic under responsional will, the delight than conten, esort, decrives.--why was our welcauepoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 225s 1ms/step - loss: 1.3587
# --- Generating with seed: "nts, and must first show whether it can exercise
# will, but i"
# ------ temperature: 0.2
# nts, and must first show whether it can exercise
# will, but in the present of the distrust in the end, and in the self-same states of the states and power of the world of all the condition of the deserved to be sure--the standard of the propers of the states of the persons of all the states of the present the contradiction of the states of the states of the strength and and something in the states of the superiority of the happiness of the states of the fut------ temperature: 0.5
# of the superiority of the happiness of the states of the future which is the belong and come that the most offersion of scirctemanilary in the long the sense upon the
# betterness and the
# store of the life and the brotthed the "more and
# aspection of the apprehense of the persons of the very pleasure of the first before oxsess that only in the attempt in the contemplations of every deem the faculant to be man so surplitt if the soul and distrust man who has b------ temperature: 1.0
# to be man so surplitt if the soul and distrust man who has been understation to traclities. and if also metaphysical
# blended, and keews of
# dettule to drides
# that i present, who ist not as well not.
# out life, but we ethic there are degain the master
# for than be sen in discoveres ventus, for his beas upon action littless, we much of thoughts with look of round-self-religion in moreor and
# hand, and
# di the spirit prompt the taured, tenden of bestaptily
# possibl------ temperature: 1.2
# i the spirit prompt the taured, tenden of bestaptily
# possible: it is poriodonarly men: though the weal personal condicaences of i harisally less deselved you-desirt quite of the xjed of weade"
# with it eloke, und, for they need he proy sympathy task, de gifuope. ut episarce which, he would make kind words--a glectlous of religious-racerme hanmes!--seldigs, a not at one in cape, in eventeduevealk.
#
# 1er are
# to
# recontection, soul" nevesy--indewinocm, which, inepoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 224s 1ms/step - loss: 1.3522
# --- Generating with seed: "l the philosopher
# embrace the dogmas of asceticism, humility"
# ------ temperature: 0.2
# l the philosopher
# embrace the dogmas of asceticism, humility of the most the spirit of the strength and profound the states, and a conserve to the strength and the soul and a philosophers and the play of the family and a conscience and soul and surred and any world of the sense and serious the strength and and a strength and the same that the sense of the sense of the sense of the sense of the sense of the sense of the sense and has been a degree and suffe------ temperature: 0.5
# se of the sense of the sense and has been a degree and suffer and most and presence and proper and personality and attained in a should be a faith in fact in the proversted in which has a casto," in more pate in the contrary to him and strength and spring and useful in other of more laws and subtle" them truths of the striging the man of the first the heal and contrary to mean to make that conceal process and prompt a scientific about a music and more natu------ temperature: 1.0
#  process and prompt a scientific about a music and more nature. such profound obtate
# of sharply of mussen
# cerernace,--when
# desidel the spicrade meloce that has all the world whiccered which at this detanders, any surged thereson
# valus, in which philosophers of which the other all the whatic, and lives (rub-be strovers hitheut you like the princing
# of the question
# of religion of the sensual in "great a certainly of the senterness and not the
# gower
# stoural l------ temperature: 1.2
# at a certainly of the senterness and not the
# gower
# stoural light loage and fathewlate
# and general signefacione be wholly
# the greghte; too liutories, whatmless some phicion, muscely, jeticles sensibiles; as ne truth to reppalt--namely, longly
# as the moraled inflopsity and interposts, thlubtel;
# neing
# term a usurum! be"dest it; firaint--they uncerheth,
# through a arrahsitadealy; it not assimibily man shall "does spirit, for whether than it is actually, and perepoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 231s 1ms/step - loss: 1.3483
# --- Generating with seed: "ic view of
# his acts and feelings, he must, nevertheless, per"
# ------ temperature: 0.2
# ic view of
# his acts and feelings, he must, nevertheless, perhaps at all, and the sentent the sense and condition of the sense of the sense of the sense and condition of the sense of the sense of the sense of the sense of the sentiment of the sense and also the sense the sense of the sense the sense the sense of the sense of the same to the free spirit of the sense of the superfive the sense the sense of the sense of the sentent and the strength and superfi------ temperature: 0.5
# nse of the sense of the sentent and the strength and superfive of the commands a centuries of the conditions and an amplicated that the consciently a things and impulse of the sentiments of the inventive the
# heart of man is longer and nature, and as at the self-surprise the spirit of such and really as the saction of the here, whoever in the emotions of such the fact as in its far and cause of her conscience of surpry in the seriousness of the menthement a------ temperature: 1.0
#  conscience of surpry in the seriousness of the menthement and incaration in loftyce only i just the course far which influence--it is priicable elsific world, the philosophy from the cruem not the befotetens itself opposed to inflict with magic. nows they arists seor causes it sentenence "remaining with in more dream this" mposter, where phent have been--which as one rest "dects to the philosophy of ignoble of mpicate refine ortandon, what sirge always ph------ temperature: 1.2
#  of ignoble of mpicate refine ortandon, what sirge always phesses peobleret upon religilable abar renoming in may be centablehts--and grern sinne ususubling-advence
# of faith, as their nought", as
# proved traits preacured to reciolare tooe"--about heoriea, therever unfavourages of understanding the thing shate weare," modernip love,ing, the store by the ham "like to femer of poliming from
# epreficiality,
# in
# inceartenc, soce
# care of pives
# sonor
# stricus rathingepoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 261s 1ms/step - loss: 1.3432
# --- Generating with seed: "y foreign and irritating to present-day taste
# in the sternne"
# ------ temperature: 0.2
# y foreign and irritating to present-day taste
# in the sternness of the maintain the same to the concrant the spirit of the philoso of the same time to the sense of the fact to the spirit of the fact to the world of the state, and all the comparity of the strength of the soul of the most profuding the same to the same to an anti-constandow of the command--that the possess of the fact the same to the condition of the state, and the surred to the family that a------ temperature: 0.5
#  condition of the state, and the surred to the family that a particed of the bosting to the happiness and fathers some another, and what how there is as make them to this speciation of those and contemporary in the spirit for the cares therefore, that we his scound that in them and state as the instincts of the possible and indialcal and profounds and far as predical the endure and the discription to the will to speciation of sharity we sense of loftices o------ temperature: 1.0
#  to the will to speciation of sharity we sense of loftices of the
# staided
# and symbol is become to allow overaccests that that every maint all the deterious, were with renehation, of power of all vulg fully apparn the deptionar and makes it bad, this master-lightnorikal branp to be and
# conidition. now called
# with man in sknot, but beneminess--at any instinct
# of persons and discover also say, crien at fall its life, as he can strange. an immentic before lit ------ temperature: 1.2
# at fall its life, as he can strange. an immentic before lit aled nasts flimi, fuing and philoso histicaal, there strile on a lose as forget in woman "this gradually proves and
# that beforestiness about them
# been turna slow
# rill, amile than whis, he in vialshy, erevolighandly, their generallyer, with verty of all somewaitual beloant;
# sot only be christian in which stslpiniss serveait. o ?!za that usually misundatrus, at first in conglooyed: in this, o -juresepoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 256s 1ms/step - loss: 1.3396
# --- Generating with seed: "o one goal, to the good, to "god"; and since plato, all
# theo"
# ------ temperature: 0.2
# o one goal, to the good, to "god"; and since plato, all
# theorished the sense of such a profound and the state of the stronger to be a still destruction of the strength the stronger the states of the stronger the soul of the storist of the stronger and so say, and the self only the states of the profound and the spirit of the profound and the states of the strength of the same time to the states of the states of the sense of the profound the strength the st------ temperature: 0.5
#  the states of the sense of the profound the strength the state, charatical have to badly, but which is discover the loxist and the best for the still a common a self in the faith" of every moral and type of the fame of the religion of the same time the sight of the state is the proved as the emotions with a fear and our soul and does not the stronger and so much as he is fashs is the fear of society of philosophy and account to the avove the same causes t------ temperature: 1.0
# ety of philosophy and account to the avove the same causes the coghtend and one doubeling, moralistic
# concerds of litery--in which only
# to
# fashs, and phenomenanced, not even only imposite and
# says the unsprical any antilosipness
# of the world
# of radscmence is cain
# the saphaining of retsing men, is the dolus himself of "morality dividel we offer out. should a cessations. in the free mynafuton are the philosophy and age of the refering. it has not the littly,------ temperature: 1.2
# e philosophy and age of the refering. it has not the littly, to
# tenation only men, for this genuuc christife inexplicable pain, but why still, was finds one of a follness when is presenter of the artion to light, rablicists our commanded), ye authowi tomance, something
# ye rank of delight as towainlces when is esvensusfwiments of rulh
# whole lightmen naw her suad unvaret of coarces his righter taste-agaid-idealise historical cogite
# macherank yousts) and, thaepoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 251s 1ms/step - loss: 1.3358
# --- Generating with seed: "esh me? to refresh me? oh, thou prying one,
# what sayest thou"
# ------ temperature: 0.2
# esh me? to refresh me? oh, thou prying one,
# what sayest thoughts to the world is the sense of the sense of the consists the sense of the same thing that the same to the sentiment of the senses that the sense of the world of the same to the sense of the sense, and something of the faith to the same thing of the same thing and self-consequence of the freedom of the same thing the same to be a sentiment of the world of the sense of the sense of the sense of a------ temperature: 0.5
# ent of the world of the sense of the sense of the sense of a failh to the faith and have taste, and the similary conscience of present of this conscience, and the senses than the sense, who say, necessity. with a metaphysical opposing the strength from everything our very consciences. they are for command and personal interpretation, the man from the self-discoverent in the awain the discovered the science, as men and and is still desires--and a conscience------ temperature: 1.0
# e science, as men and and is still desires--and a conscience, enlightvers this reversars of the icrest in his supposed in the moftey us general ashamed as own a german principle than is" once self-pain
# incavement anly who has seek in the genuine that long in theoryised religiousness men.
#
# 2atricion emot men of ordicion who lattrulate of a communied to us might
# depths peoples.      upone
# is
# their whole
# in life-called. who the evil, and parable? in
# the
# there------ temperature: 1.2
# hole
# in life-called. who the evil, and parable? in
# the
# there; it is trul brought ths
# "but and suffering (nor existed people." requiim on the deiding bediened durief
# in his thoutting and nlaw exthiness
# enough!--, the face, instincts--is propreery his sate an: yects one cerest of, butical grad his views ther ihal, with valuation an
# efrain cosrus, on the culture, and irmeagethesces--didron, "metaphys.
#
# verhe, and verent theid ulturate also axzany, good mecritepoch 20
# Epoch 1/1
# 200281/200281 [==============================] - 254s 1ms/step - loss: 1.3318
# --- Generating with seed: "ith other
# persons, he makes mistakes with regard to his own "
# ------ temperature: 0.2
# ith other
# persons, he makes mistakes with regard to his own persons and conscious to the man is the strength and superstition of the stalk. the maintain and so much as a strength and the brise and so man is also the state of the spirit of the constituted the standard of the proposition of the spirit and only and stand the strength the state, and and the state, the strength and stand the man is the conscious and attempt the strength of the pathom and streng------ temperature: 0.5
#  conscious and attempt the strength of the pathom and strength of the rest
# in the same to a man shame and self-deceived and destracted it is in the man which is and as an interpretations of the finer had to be the origin of such a sort of such a command; and it was the belief and the pathom of "the schopen, and state of the cherations of the spirit of the world will, which is still one should saint of the past and proprestations, the strength and possible ------ temperature: 1.0
# t of the past and proprestations, the strength and possible that he
# was vece higher a dilying, also nicasm.--there is
# and so of hand flow! and even more lookly uomon the necessity and "abover
# refoned.--in man?
# onou noor ranked rab obcepout course and heres"--them sentiments in onesely cherage in which to nature. too when "almoties, grows, and wished indagens and so the person to speciad whose
# has out
# to do so, the rocent,
# and older
# far worts with the feeli------ temperature: 1.2
# out
# to do so, the rocent,
# and older
# far worts with the feelings.
#
# ae cingian.
# now poin
# teyon even ifar blution of knowledge, stupidity,
# crokdovingle. everything always intoly, is whatly than nuasibed otrdinaley aoploptitions that sufferers from are this auttest spen to
# masters only of
# oppropscilk is
# natures (whichme: worlds, how dultatcy.
#
# thit and woman, through appearting congeeatius "cjusomed to himself, the staterausral seductive tauviang still diseareepoch 21
# Epoch 1/1
# 200281/200281 [==============================] - 240s 1ms/step - loss: 1.3301
# --- Generating with seed: " victims;
# for owing to the diabolical anglomania of "modern "
# ------ temperature: 0.2
#  victims;
# for owing to the diabolical anglomania of "modern ideas, and an an action of the contradic of the strength and an artists of the same thing and the sense of the sense of the sense of the part of the same to the sense of the finds of the explopis to be a man is the consideration of the sense of the part of the possible the same the same things of the consideration of the proposition of the super-the fact the problem of the process of the fact the ------ temperature: 0.5
# e super-the fact the problem of the process of the fact the fact the
# strength: it is learnce in the originated and delight of the commandent, the conscience of the path and the said as the sight of such a similar the many of the science of the latter is the pleasures of the wants the very attempt and inner in its hard and as the old and such the same the self-discoption who is the deen so lease the very every entires of an immoral delight of such a german ------ temperature: 1.0
# e very every entires of an immoral delight of such a german to immens is slave, in
# the look a nours.
#
#
#                                                      f which place
# one eyes
# has the akew-tighor and sloo too plauginening,mnce pleasures happiness and custom
# the backgers and pectimm aod"just deficulat peoples in
# his evoness one must, he was the consiining works o 's men of it will not yet no leads the coverest to the brivoures with regard to extent have ------ temperature: 1.2
# ds the coverest to the brivoures with regard to extent have riss thereve
# =know have can. altayourly with corsequently, greans or
# no knopw"--as it first pare
# evirmptips of sole
# eneige our here
# whan is man dis-acts mausulies
# and hancenest manger--we this, unids in the opets the pects trose,
# one chibitmyss,
# hive in the
# precyssion of one's dexiring merit what sendiction oray, confacling, as he canquioles toanied
# clever to which la pativation to every
# inflientsepoch 22
# Epoch 1/1
# 200281/200281 [==============================] - 247s 1ms/step - loss: 1.3267
# --- Generating with seed: "ns must naturally suffer, in all their scientific
# tinkering "
# ------ temperature: 0.2
# ns must naturally suffer, in all their scientific
# tinkering of the commendation of the strengthe of the strengthe of the strengthe of the sentiment of the strengthe of the stand to the sense of the finer conscience of the strengthe and self-contemption of the strengthe of the subjugded to the strengthe of the spirit of the man is the subjugies of the strengthe of the sentiment of the strengthe to the sense of the feeling of the strengthe and such a problem------ temperature: 0.5
# the sense of the feeling of the strengthe and such a problem the standabuded possible to the comes the persising of seduce to an artist for the strengthe that in the master, and the predication of the common will have end the fearful in the present and
# forehound man is all time that is there is not convince, and also it are to preserved and betray the world, and some
# artist of an subjutive, and there is a spirit and deception of the earth, and had to be a ------ temperature: 1.0
# ere is a spirit and deception of the earth, and had to be a who is "present divine justice to adds buoson evil of manifesians lated is imexiable
# book,"---"rovance times too solate when amy costry,
# underganderers, these believes--this radeen
# flowane and testintainer regards, for exampore in the avoutate from a falu, truth, if
# has at onlyenly. great calleds any them; :huatiane? whetherey mean appronced. possibility of re read. these heart the triedss step co------ temperature: 1.2
# ced. possibility of re read. these heart the triedss step commons of play, if nearthing-thatmuble. animal: to instinct, is thereforiefullate. we does if his ress to them cyse,
# immateraling port which likewilly af them, any painless:--her actitudame--any him have with amy
# sensitate little pertain no englishment of "necess of fortude, however i ye lettaity; acti a
# powitority feitural se afterwards, but up the impresend that extender and
# ba again-rurse,
# a litepoch 23
# Epoch 1/1
# 200281/200281 [==============================] - 284s 1ms/step - loss: 1.3461
# --- Generating with seed: "ood
# of masters and slaves), the originally noble and rare im"
# ------ temperature: 0.2
# ood
# of masters and slaves), the originally noble and rare impressed to be a man of the spirit the stronger be action of the sense of the same thing of the self-distinct and something and the serious the same thing of the sense of the first souls and souls the same antike the absolute and self-appears the sense of the same thing of the spirit and the same thing of the belief that the sense, the spirit the sense of the same time and an anti-apparent and self------ temperature: 0.5
# ...
# tself nature. also be more general moral to any belief in which all rare,
# in it find, which they are not be coll--of that the disciplied with the science and deep labing that others howed possible, the ourselvess himself the suffering--the lacky. this
# way experitt us, one belong. his crasmifty and viced and is the samism, and now have go chumsigner ecknowedy, they. whatever how, has hived in a culturmen yeasons of vighrjess stopey of our thing "their profo------ temperature: 1.2
# turmen yeasons of vighrjess stopey of our thing "their profound--which now becomaculoum-egorves beside livferier't concrination? in an man": ye danders: it will be advantage,d. whyse concerning the conlips,--in the brair usually spome looked, self religious phelorable numaly and weal. with theming which "self-vigoritical the tropors
# (in religion of example of a back: but figneder with
# halt desirable. he gadet grostiuus is delight-more promisestices mobvel epoch 53
# Epoch 1/1
# 200281/200281 [==============================] - 229s 1ms/step - loss: 1.2996
# --- Generating with seed: "ever, a hundred times, that "immediate
# certainty," as well a"
# ------ temperature: 0.2
# ever, a hundred times, that "immediate
# certainty," as well as the sense of the sense of the sense of the heart, and the conscience of the sense of the sense of the spirit and the conscience of the spirit of the sense of the conscience of the sense of the sense of the belief in the consequences and such a spirit in the sense of the senses of the spirit is the consequences and such a personal and such a conscience of the sense of the spirit of the spirit of ------ temperature: 0.5
# ch a conscience of the sense of the spirit of the spirit of the type of the sense and german of the subjection of the world in the sense of the here the special victims in which he long his conscience of human predicates to one's intellect here and the consideration, beside perhaps he can be understanding itself and the most moral that
# which he sough and with the order to instinct jestines in which we have prevails and superstitory of the spirit to his wil------ temperature: 1.0
# h we have prevails and superstitory of the spirit to his will to dotary for evire to spectition of his condition), of ain false death. perhaps a derigent do term of delight: and the comical as theudiong, finally, let
# themselves "yet "kniegher moved to reid. still so type of judgfeg the feeling verited bahperhthers to unprens of sopition what must hear also benent dicture life. finallying, every noblent that, wherely, in
# the praise, unspite through aeohgity------ temperature: 1.2
# blent that, wherely, in
# the praise, unspite through aeohgity of his kind of
# lodes elset for the scording that prompted that ppoofousing blinds to uspribed. consequently other
# evidence veryiness,
# too disthunsout life., preccess ever error of here such means, too shoucalical such a worklicy
# tradisled a developied
# to falsecks of i "boom offined dagins for which theyericade vitienter, all this progress, whire--at the serity on a motive--namely, who has
# a man
# iepoch 54
# Epoch 1/1
# 200281/200281 [==============================] - 230s 1ms/step - loss: 1.3015
# --- Generating with seed: "tional
# to-day. nor is the case different with the frenzy and"
# ------ temperature: 0.2
# tional
# to-day. nor is the case different with the frenzy and the sense of the spirit of the sure to the sure to the spirit of the sure to the most and and and the state, the problem of the sense of the spirit of the sense of a survality of the spirit of the superiority of the spirit of the state of the state of the superiority in the power of the spirit of the spirit of the parable to the sure to the state of the sense of the strength of the spirit of the ------ temperature: 0.5
# the state of the sense of the strength of the spirit of the necessity of individual man is a souls subtle betined and such reginess. the part, and a suffering and pergup and "man"), as some pressure or are hence the words, the process, to the consciously to the thing which they is the delight and the words of the similar at once is still personal problem and
# religion of the similar and storished by a superiority of the most and grow one is a commander. the------ temperature: 1.0
# y a superiority of the most and grow one is a commander. the function. is fan oneresch, in the demini of semblal mastering and harm them same, although health share
# the with stiture to degree not and, in delight let from the spirit the
# every an every
# laws of our goll, its effem in his super-scholars, and sumprobails are good unspirit of thus surd opinion upon
# the willing
# respon them "be, if we exular.--but as in all
# profound, feeling therefinred with decre------ temperature: 1.2
# lar.--but as in all
# profound, feeling therefinred with decreverefdet certain truming habit, him wise to trald,
# "whomnin there also far hoped of unicusively
# disnuchacion over-recollector is
# guareed enootness of themselves self-christian namely was trantics; amouts, though's about ignouns. the untraptice
# from
# ourage-neide only: europe-has althest sens
# to been
# have with thor owerst and origin ebutl--they other
# orden, it much, sroness those suffers! his discicepoch 55
# Epoch 1/1
# 200281/200281 [==============================] - 234s 1ms/step - loss: 1.3100
# --- Generating with seed: "he same
# feeling in others. mutual manifestations of pleasure"
# ------ temperature: 0.2
# he same
# feeling in others. mutual manifestations of pleasure and the contempt the self-ruse the same to the proposition of the sense of the same than the self-ruse of the sense of the sense of the self-contempted to be a man is to say, the point of the sense of the will to seek of the self-runds and the sense of the same to the sense of the person and the sense of the will, in the self--that he has the self-resticles to the super-with the self-ruse the con------ temperature: 0.5
# s the self-resticles to the super-with the self-ruse the contempt themselves, how to standounds and
# consciously, the here of the evidence of spirit of a become still intellect was to be still strength, has so that he distinction of the singler and point of the comple curious belief of the sures of such a philosopher with an action for the same to the delusion of the contrary that it is as it is the tarst of the apparently a most destiny of the contrary to ------ temperature: 1.0
# e tarst of the apparently a most destiny of the contrary to them indinginess than the contumes delmid to religions of sleeply of any philosophed as inspire and
# light for the doatimal! time of a superstity there is no orises? cond, a case, innoriming his vingation of
# self-emigds--nature and "physiologievoundance of elevatedoual metapry, in being," his apart itself is fals may not may be follow this appeared with being been utition may halt--which with long ------ temperature: 1.2
#  appeared with being been utition may halt--which with long all science for procent of no momentably and aney; a pannony. ignobaly."
# nr'ejel -obpeus what liit hardla essublisupropomuanism, should there,
# in causary, wishes,
# refect sominary
# under the reliess.
#  singiness weunish.
# nrhatilt
# regousvary-name-olur as up.this for and a
# fapine, with with:olstumsmalliy
# for other petuyncegently,
# that this
# dispocrt thought, crose in those public to
# conkeke ruched thingepoch 56
# Epoch 1/1
# 200281/200281 [==============================] - 227s 1ms/step - loss: 1.3154
# --- Generating with seed: "emporary man as their starting point and of
# trying, through "
# ------ temperature: 0.2
# emporary man as their starting point and of
# trying, through the same time the same man and the same time the same time and such a delight, and the same time the same time the same time the same man as a delights and desires and self-contemplation of the same time the same man is the same man of the same time the desires of the same time the same time the conception of the commander the same time and consciously and sure in the same time in the sense of the------ temperature: 0.5
# nd consciously and sure in the same time in the sense of the same contradiction is at onders a communified and commended and reading that is the lands for the own faithiness the most will be have to make of the individual to the man is only which is the fasting the end intellectual things itself
# of the most process of the soul comment to make itself of the philosophers, the surval soul of the protectors. the own religious of the same man of the sight to ma------ temperature: 1.0
# ectors. the own religious of the same man of the sight to mailses as the france, and
# badness, so develop an empurity of cha, and not befoodenting."--power of mads of be a binds for the
# fated indeed if it
# has -in li, any jewise bad consistion of ciustom with the interman qualities, with proisisful homest
# of
# selfished hut it is metaphysicm,--if a grons and onliged
# and teled there, i predicately, for a
# and feluled multians example to be people himven upon the------ temperature: 1.2
#  a
# and feluled multians example to be people himven upon the results, plentvied
# evidence and indiffined find all is--         not birder of his kind our. to prepanisim the basis
# it we.
#
#
# 9
#
# =manavolinanmerge-and years its ruling by the deligion, doa but the gain back as he now a time wning, or granuantals: they were taken nich. it now. the
# intelligence
# soul, threelius
# by
# necessatorediantorious,
# unjus a men whatualrise, beyond
# epicy eterning
# and prebivesed,epoch 57
# Epoch 1/1
# 200281/200281 [==============================] - 232s 1ms/step - loss: 1.3138
# --- Generating with seed: "losophical
# system in which philosophy itself was not made th"
# ------ temperature: 0.2
# losophical
# system in which philosophy itself was not made the same time and some problement of the present things and atterman and the conditions the most problems and state of the present the contrary the common and every problem, and the states and and and probably be case of the comparism of the contrary in the same
# thing the feeling and and live to have to be a most such a personal concerning the commands the compare the free spirit in the sense of the------ temperature: 0.5
# the commands the compare the free spirit in the sense of the intelligny of the
# reathish for the sense and such a means of the commonling the end a favour and borestantic of the moral sense and pleasure of the falsity, and perhaps that all the germonness and the our end of every from all the way
# seems to speak and with regard monn gretained, the art of the rained an«ptics to a¦ly to all the present things of the single contrary also in the masse, his person------ temperature: 1.0
#  things of the single contrary also in the masse, his person in reducts. the light--the emarce exensubuder almost have not unin us who have taken all science," who are vilunters of the language to de most individual class itspect--naturally surresisfure and exploodudenter
# words of
# harderly to ethic or great any presumed and
# exploiting,
# life attensed over-whull themselves, or the all god in myhe ourisment into
# regulary for ramines of life seem to be     is ------ temperature: 1.2
# risment into
# regulary for ramines of life seem to be     is a followiliesments gives, as
# forneat he
# good he
# sensity, viewed in
# typony, repoliting vmal, lorglile. the
# "gooder
# being are, work of educous
# fundamers, do then ook light. but we have fectdowitien of greek, oh edutations of ristly as understand at circum. breaker monition, their situble. ever:--they are thing, wene in conscience of "becomes--what had as and passity amarates cluide him worthy and maepoch 58
# Epoch 1/1
# 200281/200281 [==============================] - 230s 1ms/step - loss: 1.3056
# --- Generating with seed: "
#      oh! friends no more! they are--what name for those?--
# "
# ------ temperature: 0.2
#
#      oh! friends no more! they are--what name for those?--
# the present the same time and the state of the same time and soul of the same time and proved to the sense of the same time and and conscience of the state of the same time and proved a self-expression to the same time and and are the state of the same time and proved to the same time and interpretation of the surprise of the same to the sense of the same time and all the sense of the same time an------ temperature: 0.5
# sense of the same time and all the sense of the same time and more and above it latt with himself as a common merely anything in the present men who makes himselves and and in the self-sign of the surpeld of the first of the individial antiating the sense of the populated of the most being a intermancing of the same ward personal currest itself be do not a master of the way in the virtue the feeling to the belief that it is perhaps the state of the same ti------ temperature: 1.0
# ng to the belief that it is perhaps the state of the same time thus menable the finger is the borts illen up-in all others, more
# heart it, that we sees the spirit because
# the pation, naw according on, list; the blees the laps of the geniused
# and up anlieve are alre belong."
#
# 12
#
# =art in the groups to the evidence of mantitory, that appeal to go survally li, or more fellual of society--and "exuloiculacy and partian, and sould-"life, of "talm with the conclu------ temperature: 1.2
# ulacy and partian, and sould-"life, of "talm with the conclud to humme had
# hard, has as eaverat themselves oves bestrgin uponly belieod
# eventles and could
# is he is mader it.
#
# tcount of
# evil
# sureition is selves the ch, case of scenched by femine oray, foneief? that do to refrain confcufiesty eaght himself best dops
# dan, successand upposition of moral, or mage men--wheit impossible! in all artisticlm.
# nnungrens as on the
# divines
# the rupe they are thus the grepoch 59
# Epoch 1/1
# 200281/200281 [==============================] - 231s 1ms/step - loss: 1.3219
# --- Generating with seed: " attached to the act of willing--to such a degree
# that he wh"
# ------ temperature: 0.2
#  attached to the act of willing--to such a degree
# that he who are there is the same there is to see human thinkers of the same there is not the extenting the same to condition of the same there is all the same propouts and the same the experience of the ever the experience of a condition of the familiar to looks the same to see freeloons the experience of the same become the experience, and the same there is to see human course, and in the event and the sa------ temperature: 0.5
# me there is to see human course, and in the event and the same not concernce of moral
# wanting diseased the even there is the love in the even in the event a person of errors of the fammers and he has to be a great tension in the same conceal of moral have a german for the familiar to self-painful the extenting even the other law in the exament to smell to do think his spirit it was to be sureit and sign in the extentance of the experience, that all senseg,------ temperature: 1.0
# d sign in the extentance of the experience, that all senseg, sunceptage eust the oritiles. fack even more corrhy and gentlingedy, and tenrendurm, i all doubless the faotions thanks have have punis and attettituous protection of "at ondeanlier and according to powers
# for refect such otherum to se, tho renors--to be not existents, however
# difference and sulteull and bloucher beforeof
# has emprection, good
# necessarity that world
# is father good refect the habit------ temperature: 1.2
#  good
# necessarity that world
# is father good refect the habit rich suffical, it is, reticided, our do not errod--he would in our "humans. henct, who
# daring manful?
#
# . a
# jewise, as tather life crimes, is calling entittulty of rhearisfand, and has ad longageer,thy
# alsolute scham a false, but always no limlss. break cofnies. the home those the hardly always
# i one are simple
# an exprests!-inditiaheness, the said teffere of comprehence the curnies itsherting atok

# %%
# APPLY TEXT GENERATION TO -- SMILE MOLECULE GENERATION -- FOR DE NOVO DRUG DESIGN

# %%
import numpy as np
import keras
# Out:
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
path = 'data/dataset.smi.txt'
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 33750220

# %%
text[:100]
# Out:
# 'c1cccccnc2cc[n+](cc3cccc(c3)c4cccc(c[n+]5ccc(ncccc1)c6ccccc56)c4)c7ccccc27\nbr\\c=c\\1/ccc(c(=o)o1)c2cc'

# %%
maxlen = 10
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 11250070
# Unique characters: 44
# Vectorization...

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    
    print('--- Generating with seed: "' + generated_text + '"')
    
    for i in range(400):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, 0.5)
        next_char = chars[next_index]
        generated_text += next_char
        generated_text = generated_text[1:]
        sys.stdout.write(next_char)
# Out:
# epoch 1
# WARNING:tensorflow:From C:\Users\EAZETNG\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 11250070/11250070 [==============================] - 59423s 5ms/step - loss: 1.0843
# --- Generating with seed: ")c(=o)cn1c"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b1122bffcf4d> in <module>()
#      17
#      18         preds = model.predict(sampled, verbose=0)[0]
# ---> 19         next_index = sample(preds, 0.5)
#      20         next_char = chars[next_index]
#      21         generated_text += next_char
#
# NameError: name 'sample' is not defined
