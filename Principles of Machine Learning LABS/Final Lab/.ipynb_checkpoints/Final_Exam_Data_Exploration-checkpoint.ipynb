# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %matplotlib inline

# %%
ams_df = pd.read_csv('AW_AveMonthSpend.csv')
bike_buyers_df = pd.read_csv('AW_BikeBuyer.csv')
cust_df = pd.read_csv('AdvWorksCusts.csv')

# %%
# AWS_dataset = pd.concat([AWS_df1, AWS_df2, AWS_df3])
AWS_dataset = cust_df
AWS_dataset['AveMonthSpend'] = ams_df['AveMonthSpend']
AWS_dataset.head()
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
#
#           AddressLine1 AddressLine2         City StateProvinceName  \
# 0      3761 N. 14th St          NaN  Rockhampton        Queensland
# 1           2243 W St.          NaN      Seaford          Victoria
# 2     5844 Linden Land          NaN       Hobart          Tasmania
# 3     1825 Village Pl.          NaN   North Ryde   New South Wales
# 4  7553 Harness Circle          NaN   Wollongong   New South Wales
#
#        ...         Education    Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0      ...        Bachelors   Professional      M             M             1
# 1      ...        Bachelors   Professional      M             S             0
# 2      ...        Bachelors   Professional      M             M             1
# 3      ...        Bachelors   Professional      F             S             0
# 4      ...        Bachelors   Professional      F             S             1
#
#   NumberCarsOwned NumberChildrenAtHome TotalChildren  YearlyIncome  \
# 0               0                    0             2        137947
# 1               1                    3             3        101141
# 2               1                    3             3         91945
# 3               1                    0             0         86688
# 4               4                    5             5         92771
#
#    AveMonthSpend
# 0             89
# 1            117
# 2            123
# 3             50
# 4             95
#
# [5 rows x 24 columns]

# %%
AWS_dataset['AveMonthSpend'].describe()
# Out:
# count    16519.000000
# mean        72.405957
# std         27.285370
# min         22.000000
# 25%         52.000000
# 50%         68.000000
# 75%         84.000000
# max        176.000000
# Name: AveMonthSpend, dtype: float64

# %%
AWS_dataset['BikeBuyer'] = bike_buyers_df['BikeBuyer']
AWS_dataset['BikeBuyer'].value_counts()
# Out:
# 0    11030
# 1     5489
# Name: BikeBuyer, dtype: int64

# %%
AWS_dataset.groupby(['Occupation']).median()
# Out:
#                 CustomerID  HomeOwnerFlag  NumberCarsOwned  \
# Occupation
# Clerical           20878.0            1.0              1.0
# Management         19685.5            1.0              2.0
# Manual             20794.5            1.0              1.0
# Professional       20216.0            1.0              2.0
# Skilled Manual     20271.0            1.0              1.0
#
#                 NumberChildrenAtHome  TotalChildren  YearlyIncome  \
# Occupation
# Clerical                         0.0            1.0       49387.0
# Management                       1.0            3.0      118780.0
# Manual                           0.0            1.0       21722.5
# Professional                     1.0            2.0       99046.0
# Skilled Manual                   0.0            1.0       66481.0
#
#                 AveMonthSpend
# Occupation
# Clerical                 62.0
# Management               79.0
# Manual                   57.0
# Professional             77.0
# Skilled Manual           66.0

# %%
AWS_dataset.groupby(['MaritalStatus']).median()
# Out:
#                CustomerID  HomeOwnerFlag  NumberCarsOwned  \
# MaritalStatus
# M                 19827.0            1.0              2.0
# S                 20908.5            1.0              1.0
#
#                NumberChildrenAtHome  TotalChildren  YearlyIncome  \
# MaritalStatus
# M                               0.0            2.0       81942.0
# S                               0.0            1.0       68711.0
#
#                AveMonthSpend
# MaritalStatus
# M                       74.0
# S                       62.0

# %%
AWS_dataset.groupby(['Gender']).median()
# Out:
#         CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# Gender
# F          20182.5            1.0              2.0                   0.0
# M          20262.0            1.0              2.0                   0.0
#
#         TotalChildren  YearlyIncome  AveMonthSpend
# Gender
# F                 2.0       70886.5           52.0
# M                 2.0       84726.0           79.0

# %%
AWS_dataset.groupby(['NumberChildrenAtHome']).median()
# Out:
#                       CustomerID  HomeOwnerFlag  NumberCarsOwned  \
# NumberChildrenAtHome
# 0                        20240.0            1.0              1.0
# 1                        20989.0            1.0              1.0
# 2                        19689.5            1.0              1.0
# 3                        20043.0            1.0              2.0
# 4                        19642.5            1.0              3.0
# 5                        19974.5            1.0              3.0
#
#                       TotalChildren  YearlyIncome  AveMonthSpend
# NumberChildrenAtHome
# 0                               1.0       66932.5           57.0
# 1                               2.0       70958.0           68.0
# 2                               2.0       80453.0           79.0
# 3                               3.0       97095.5           89.5
# 4                               4.0      117656.0          101.0
# 5                               5.0      125559.5          110.0

# %%
AWS_dataset['BirthDate'] = pd.to_datetime(AWS_dataset['BirthDate'])
AWS_dataset['Age'] = [1998 - int(x) for x in AWS_dataset['BirthDate'].dt.year]
AWS_dataset[['BirthDate', 'Age']].head(20)
# Out:
#     BirthDate  Age
# 0  1966-04-08   32
# 1  1965-05-14   33
# 2  1965-08-12   33
# 3  1968-02-15   30
# 4  1968-08-08   30
# 5  1965-08-05   33
# 6  1965-12-06   33
# 7  1964-05-09   34
# 8  1964-07-07   34
# 9  1964-04-01   34
# 10 1964-02-06   34
# 11 1963-11-04   35
# 12 1968-01-18   30
# 13 1968-08-06   30
# 14 1968-05-09   30
# 15 1979-02-27   19
# 16 1979-04-28   19
# 17 1978-03-07   20
# 18 1978-09-20   20
# 19 1978-10-11   20

# %%
fig = plt.figure(figsize=(7,6)) # define plot area
ax = fig.gca() # define axis   
AWS_dataset.plot.scatter(x = 'Age', y = 'AveMonthSpend', ax = ax)
ax.set_title('Scatter plot of Age vs. AveMonthSpend') # Give the plot a main title
ax.set_xlabel('Age') # Set text for the x axis
ax.set_ylabel('AveMonthSpend')# Set text for y axis
plt.show()

# %%
shapes = ['+', 'o', 's', 'x', '^'] # pick distinctive shapes
unique_cats = AWS_dataset['Gender'].unique()
sns.set_style("whitegrid")
for i, cat in enumerate(unique_cats): # loop over the unique categories
    temp = AWS_dataset[AWS_dataset['Gender'] == cat]
    sns.jointplot('Age', 'AveMonthSpend', data=temp, marker = shapes[i], label = cat,
                scatter_kws={"alpha":0.2}, fit_reg = False, color = 'blue', kind ='kde')
plt.title('Scatter plot of Age vs. AveMonthSpend') # Give the plot a main title
plt.xlabel('Age') # Set text for the x axis
plt.ylabel('AveMonthSpend')# Set text for y axis
plt.legend()
plt.show()
# Out:
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'marker', 'label', 'scatter_kws', 'fit_reg'
#   s)
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'marker', 'label', 'scatter_kws', 'fit_reg'
#   s)
# No handles with labels found to put in legend.

# %%
AWS_dataset['Gender'].value_counts()
# Out:
# M    8351
# F    8168
# Name: Gender, dtype: int64

# %%
def plot_box(dataset, col_x = 'Gender', col_y = 'AveMonthSpend'):
        sns.set_style("whitegrid")
        sns.boxplot(col_x, col_y, data=dataset)
        plt.xlabel(col_x) # Set text for the x axis
        plt.ylabel(col_y)# Set text for y axis
        plt.show()
        
plot_box(AWS_dataset)

# %%
AWS_dataset.groupby(['Gender']).mean()
# Out:
#           CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# Gender
# F       20185.410015       0.675441         1.498898              0.991308
# M       20281.970662       0.672375         1.503054              0.992695
#
#         TotalChildren  YearlyIncome  AveMonthSpend        Age
# Gender
# F            2.010651  71355.231024      56.631978  36.500367
# M            2.001916  84741.496946      87.834271  36.415160

# %%
AWS_dataset.groupby(['BikeBuyer']).median()
# Out:
#            CustomerID  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# BikeBuyer
# 0             20286.5            1.0              1.0                   0.0
# 1             20055.0            1.0              2.0                   2.0
#
#            TotalChildren  YearlyIncome  AveMonthSpend   Age
# BikeBuyer
# 0                    1.0       65955.5           60.0  37.0
# 1                    3.0       96122.0           82.0  34.0

# %%
counts = AWS_dataset[['dummy', 'BikeBuyer', col]].groupby(['BikeBuyer', col], as_index = False).count()
temp = counts[counts['BikeBuyer'] == 0][[col, 'dummy']]
_ = plt.figure(figsize = (10,4))
plt.subplot(1, 2, 1)
temp = counts[counts['BikeBuyer'] == 0][[col, 'dummy']]
plt.bar(temp[col], temp.dummy)
plt.xticks(rotation=90)
plt.title('Counts for ' + col + '\n Bought Bike')
plt.ylabel('count')
plt.subplot(1, 2, 2)
temp = counts[counts['BikeBuyer'] == 1][[col, 'dummy']]
plt.bar(temp[col], temp.dummy)
plt.xticks(rotation=90)
plt.title('Counts for ' + col + '\n Didn\'t Buy Bike')
plt.ylabel('count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-b9cfd07aff2b> in <module>()
# ----> 1 counts = AWS_dataset[['dummy', 'BikeBuyer', 'Occupation']].groupby(['BikeBuyer', 'Occupation'], as_index = False).count()
#       2 temp = counts[counts['BikeBuyer'] == 0][['Occupation', 'dummy']]
#       3 _ = plt.figure(figsize = (10,4))
#       4 plt.subplot(1, 2, 1)
#       5 temp = counts[counts['BikeBuyer'] == 0][['Occupation', 'dummy']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['dummy'] not in index"
