# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
clients_df = pd.read_csv('week3_challenge.csv')
clients_df.head(200).T
# Out:
#                                                                              0    \
# Unnamed: 0                                                                     0
# createdAt_Month                                                           201812
# Reason                                       Client did not meet approval score.
# application_id                              WRYRieZlqBsT6w53b2HDpA_1544015103274
# SystemCustomerID                                                       334043596
# SystemLoanID                                                        302881418623
# income_source                                                             credit
# income_verified                                                             True
# next_loan_number                                                               1
# country                                                                       NG
# DecisionFlag                                                            Declined
# ...

# %%
print(clients_df.shape)
clients_df.dtypes
# Out:
# (11993, 290)
# Unnamed: 0                                      int64
# createdAt_Month                                 int64
# Reason                                         object
# application_id                                 object
# SystemCustomerID                                int64
# SystemLoanID                                    int64
# income_source                                  object
# income_verified                                  bool
# next_loan_number                                int64
# country                                        object
# DecisionFlag                                   object
# Product                                        object
# Income                                        float64
# ID                                             object
# ApplicationID                                  object
# __v                                           float64
# CompletedAt                                    object
# ...

# %%
clients_df.drop("demofeatures_payweek", axis=1, inplace = True)
clients_df.drop("obiResult_scorecard", axis=1, inplace = True)
clients_df.drop("obiResult_score", axis=1, inplace = True)
clients_df.drop("obiResult_riskLevel", axis=1, inplace = True)
clients_df.drop("obiResult_ratingClass", axis=1, inplace = True)
clients_df.drop("obiResult_ncngav2Id", axis=1, inplace = True)

# %%
clients_df.shape
# Out:
# (11993, 284)

# %%
clients_df.shape[0] * 0.3
# Out:
# 3597.9

# %%
clients_df.head(100).T
# Out:
#                                                                               0   \
# Unnamed: 0                                                                     0
# createdAt_Month                                                           201812
# Reason                                       Client did not meet approval score.
# application_id                              WRYRieZlqBsT6w53b2HDpA_1544015103274
# SystemCustomerID                                                       334043596
# SystemLoanID                                                        302881418623
# income_source                                                             credit
# income_verified                                                             True
# next_loan_number                                                               1
# country                                                                       NG
# DecisionFlag                                                            Declined
# ...

# %%
clients_df["score"].isnull().sum().sum()
# Out:
# 5695

# %%
clients_df["demofeatures_debt_to_income_ratio"].isnull().sum().sum()
# Out:
# 8840

# %%
clients_df.drop("score", axis=1, inplace = True)
clients_df.drop("demofeatures_debt_to_income_ratio", axis=1, inplace = True)

# %%
clients_df["demofeatures_level_of_education"].isnull().sum().sum()
# Out:
# 2290

# %%
clients_df["demofeatures_employment_status_clients"].isnull().sum().sum()
# Out:
# 607

# %%
clients_df.shape
# Out:
# (11993, 282)

# %%
def show_column_null_counts():
    for col in clients_df.columns:
        print(col, ":     ", clients_df[col].isnull().sum())
        
show_column_null_counts()
# Out:
# Unnamed: 0 :      0
# createdAt_Month :      0
# Reason :      0
# application_id :      0
# SystemCustomerID :      0
# SystemLoanID :      0
# income_source :      0
# income_verified :      0
# next_loan_number :      0
# country :      0
# DecisionFlag :      0
# Product :      0
# Income :      0
# ID :      2
# ApplicationID :      2
# __v :      2
# CompletedAt :      2
# demofeatures_net_income_band :      2
# demofeatures_appweek :      2
# demofeatures_time_at_employer_mths :      941
# demofeatures_age_at_application_yrs :      2
# demofeatures_device :      1750
# demofeatures_loan_purpose :      2
# demofeatures_time_curr_address :      2
# demofeatures_residence_state :      2
# demofeatures_bank_name :      2
# demofeatures_level_of_education :      2290
# demofeatures_marital_status :      4
# demofeatures_residential_status :      30
# demofeatures_employment_status_clients :      607
# demofeatures_gender :      2
# demofeatures_num_children :      2
# ...

# %%
for col in clients_df.columns:
    if clients_df[col].isnull().sum() > clients_df.shape[0] * 0.3:
        clients_df.drop(col, axis=1, inplace = True)

# %%
clients_df.shape
# Out:
# (11993, 272)

# %%
show_column_null_counts()
# Out:
# Unnamed: 0 :      0
# createdAt_Month :      0
# Reason :      0
# application_id :      0
# SystemCustomerID :      0
# SystemLoanID :      0
# income_source :      0
# income_verified :      0
# next_loan_number :      0
# country :      0
# DecisionFlag :      0
# Product :      0
# Income :      0
# ID :      2
# ApplicationID :      2
# __v :      2
# CompletedAt :      2
# demofeatures_net_income_band :      2
# demofeatures_appweek :      2
# demofeatures_time_at_employer_mths :      941
# demofeatures_age_at_application_yrs :      2
# demofeatures_device :      1750
# demofeatures_loan_purpose :      2
# demofeatures_time_curr_address :      2
# demofeatures_residence_state :      2
# demofeatures_bank_name :      2
# demofeatures_level_of_education :      2290
# demofeatures_marital_status :      4
# demofeatures_residential_status :      30
# demofeatures_employment_status_clients :      607
# demofeatures_gender :      2
# demofeatures_num_children :      2
# ...

# %%
int_df = clients_df.select_dtypes(include = ['int64'])
float_df = clients_df.select_dtypes(include = ['float'])

client_num_df = float_df

for col in int_df.columns:
    client_num_df[col] = int_df[col]
    
client_num_df.shape
# Out:
# C:\Users\EAZETNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# (11993, 249)

# %%
client_num_df.dtypes
# Out:
# Income                                        float64
# __v                                           float64
# demofeatures_net_income_band                  float64
# demofeatures_appweek                          float64
# demofeatures_age_at_application_yrs           float64
# demofeatures_num_children                     float64
# smsFeatures_minmaxdebit_tot                   float64
# smsFeatures_mixmaxcredit_tot                  float64
# smsFeatures_minbal_tot                        float64
# smsFeatures_pers_sms_snt_flag                 float64
# smsFeatures_pers_sms_rec_flag                 float64
# smsFeatures_arrears_flag                      float64
# smsFeatures_isp_flag                          float64
# smsFeatures_sattv_flag                        float64
# smsFeatures_avg_mly_airtimecredit_val         float64
# smsFeatures_avg_airtimecredit_tx_val          float64
# smsFeatures_tot_airtimecredit_vol             float64
# ...

# %%
client_num_df.fillna(0)
# Out:
#           Income  __v  demofeatures_net_income_band  demofeatures_appweek  \
# 0      200000.00  0.0                      200000.0                   1.0
# 1       80000.00  0.0                      100000.0                   1.0
# 2       39500.00  0.0                       50000.0                   2.0
# 3       50000.00  0.0                       50000.0                   1.0
# 4       20000.00  0.0                       75000.0                   3.0
# 5       50000.00  0.0                       50000.0                   4.0
# 6       75000.00  0.0                       75000.0                   2.0
# 7       10000.00  0.0                       25000.0                   3.0
# 8       22000.00  0.0                       50000.0                   1.0
# 9       25000.00  0.0                       25000.0                   3.0
# 10      40000.00  0.0                      350000.0                   4.0
# 11      50000.00  0.0                      100000.0                   2.0
# ...

# %%
# x = client_num_df.loc[:, client_num_df.columns].values
# x = StandardScaler().fit_transform(x)

client_num_df = StandardScaler().fit_transform(client_num_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-56311db38df5> in <module>()
#       2 # x = StandardScaler().fit_transform(x)
#       3
# ----> 4 client_num_df = StandardScaler().fit_transform(client_num_df)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# ...
